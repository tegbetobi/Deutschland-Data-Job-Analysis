# %%
import pandas as pd

# %%
df = pd.read_csv('data_jobs.csv')
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df[['job_title_short','job_location']]
# Out:
#              job_title_short                         job_location
# 0       Senior Data Engineer                        Watertown, CT
# 1               Data Analyst         Guadalajara, Jalisco, Mexico
# 2              Data Engineer                      Berlin, Germany
# 3              Data Engineer                      San Antonio, TX
# 4              Data Engineer                       Washington, DC
# ...                      ...                                  ...
# 785736     Software Engineer                            Singapura
# 785737          Data Analyst                   Bad Rodach, Jerman
# 785738      Business Analyst                             Malaysia
# 785739         Data Engineer  Newark, New Jersey, Amerika Serikat
# 785740     Software Engineer                                India
#
# [785741 rows x 2 columns]

# %%
df.iloc[4:10]
# Out:
#         job_title_short                                 job_title  \
# 4         Data Engineer                    Data Engineer- Sr Jobs
# 5         Data Engineer                         GCP Data Engineer
# 6  Senior Data Engineer         Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                             Data Engineer
# 8      Business Analyst  Technology & Operations Business Analyst
# 9        Data Scientist                         Data Scientist II
#
#           job_location             job_via         job_schedule_type  \
# 4       Washington, DC  via Clearance Jobs                 Full-time
# 5             Anywhere    via ZipRecruiter  Contractor and Temp work
# 6         Dearborn, MI        via LinkedIn                 Full-time
# 7             Anywhere        via LinkedIn                 Full-time
# 8  Copenhagen, Denmark     via Trabajo.org                 Full-time
# 9             Anywhere    via ZipRecruiter                 Full-time
#
# ...

# %%
df.iloc[4:10,2]
# Out:
# 4         Washington, DC
# 5               Anywhere
# 6           Dearborn, MI
# 7               Anywhere
# 8    Copenhagen, Denmark
# 9               Anywhere
# Name: job_location, dtype: object

# %%
df.iloc[4:10,0:2]
# Out:
#         job_title_short                                 job_title
# 4         Data Engineer                    Data Engineer- Sr Jobs
# 5         Data Engineer                         GCP Data Engineer
# 6  Senior Data Engineer         Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                             Data Engineer
# 8      Business Analyst  Technology & Operations Business Analyst
# 9        Data Scientist                         Data Scientist II

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.count()
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %% [raw]
# df.describe()

# %%
df['job_location'].unique()
# Out:
# array(['Watertown, CT', 'Guadalajara, Jalisco, Mexico', 'Berlin, Germany',
#        ..., 'Heidelberg, Jerman', 'Bad Rodach, Jerman',
#        'Newark, New Jersey, Amerika Serikat'], dtype=object)

# %%
df['job_location'].count()
# Out:
# 784696

# %%
df['job_location']
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 785736                              Singapura
# 785737                     Bad Rodach, Jerman
# 785738                               Malaysia
# 785739    Newark, New Jersey, Amerika Serikat
# 785740                                  India
# Name: job_location, Length: 785741, dtype: object

# %%
df[df['job_location'].str.contains('germany', case=False, na=False)]
# Out:
#               job_title_short  \
# 2               Data Engineer
# 34               Data Analyst
# 64        Senior Data Analyst
# 78      Senior Data Scientist
# 104         Software Engineer
# ...                       ...
# 785176           Data Analyst
# 785292         Data Scientist
# 785332         Data Scientist
# 785500         Data Scientist
# 785682         Data Scientist
#
#                                                 job_title  \
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 34      Data Analyst als Marketing Manager Automation ...
# 64                                    Senior Data Analyst
# 78                                     Senior Data Expert
# 104                   Senior Software Engineer - Metadata
# ...                                                   ...
# 785176                               Data Analyst (m/w/d)
# 785292                 Developer / Data Scientist (m/f/d)
# 785332  Consultant Data Science & berufsbegleitender M...
# ...

# %%
df[df.job_title_short == 'Data Scientist']
# Out:
#        job_title_short                                          job_title  \
# 9       Data Scientist                                  Data Scientist II
# 17      Data Scientist                             Data Science Team Lead
# 19      Data Scientist                                     Data Scientist
# 20      Data Scientist                                     Data Scientist
# 21      Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 785689  Data Scientist                           Data Scientist -50065385
# 785690  Data Scientist                    Customer Master Data Specialist
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
# 785697  Data Scientist                      Data Science Python modelling
# 785725  Data Scientist                                 Analytics Engineer
#
#                              job_location  \
# ...

# %%
df[(df.job_title_short == 'Data Scientist') & (df.salary_year_avg > 100000)]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 116     Data Scientist                                     Data Scientist
# 212     Data Scientist       NATOIS-0008 Data Scientist (NS) - TUE 13 Jun
# 257     Data Scientist  Senior Bioinformatics Research Scientist- Data...
# ...                ...                                                ...
# 785488  Data Scientist                                     Data Scientist
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# ...

# %%
df[(df.job_title_short == 'Data Scientist') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 116     Data Scientist                                     Data Scientist
# 212     Data Scientist       NATOIS-0008 Data Scientist (NS) - TUE 13 Jun
# 257     Data Scientist  Senior Bioinformatics Research Scientist- Data...
# ...                ...                                                ...
# 785488  Data Scientist                                     Data Scientist
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# ...

# %%
df.job_posted_date
# Out:
# 0         2023-06-16 13:44:15
# 1         2023-01-14 13:18:07
# 2         2023-10-10 13:14:55
# 3         2023-07-04 13:01:41
# 4         2023-08-07 14:29:36
#                  ...
# 785736    2023-03-13 06:16:16
# 785737    2023-03-12 06:18:18
# 785738    2023-03-12 06:32:36
# 785739    2023-03-12 06:32:15
# 785740    2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: object

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_date']
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df.job_posted_month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_month, Length: 785741, dtype: int32

# %%
df.sort_values('job_posted_date', inplace = True)

# %%
df.dropna(subset=['job_posted_date'], how='all')
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short','job_location'])['salary_year_avg'].mean()
# Out:
# job_title_short    job_location
# Business Analyst   's-Graveland, Netherlands                          NaN
#                    's-Hertogenbosch, Netherlands                      NaN
#                    10th of Ramadan City, Egypt                        NaN
#                    6th of October City, Egypt                         NaN
#                    A Coruña, Spain                                    NaN
#                                                                        ..
# Software Engineer  Ümraniye, Elmalıkent, Ümraniye/İstanbul, Türkiye   NaN
#                    İstanbul, Turkey                                   NaN
#                    İstanbul, Türkiye                                  NaN
#                    Łódź, Poland                                       NaN
#                    Žilina, Slovakia                                   NaN
# Name: salary_year_avg, Length: 42721, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].mean()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst              91082.612833        42.723415
# Cloud Engineer               111268.453846        45.560715
# Data Analyst                  93841.907854        38.106918
# Data Engineer                130125.604250        57.196998
# Data Scientist               135988.837171        49.361403
# Machine Learning Engineer    126774.315972        48.477935
# Senior Data Analyst          113911.363665        47.661218
# Senior Data Engineer         145840.611624        62.848496
# Senior Data Scientist        154206.292996        54.105631
# Software Engineer            113393.760054        46.452019

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].agg(['min', 'max', 'mean'])
# Out:
#                           salary_year_avg                           \
#                                       min       max           mean
# job_title_short
# Business Analyst                  16500.0  387460.0   91082.612833
# Cloud Engineer                    42000.0  280000.0  111268.453846
# Data Analyst                      25000.0  650000.0   93841.907854
# Data Engineer                     15000.0  525000.0  130125.604250
# Data Scientist                    27000.0  960000.0  135988.837171
# Machine Learning Engineer         30000.0  325000.0  126774.315972
# Senior Data Analyst               30000.0  425000.0  113911.363665
# Senior Data Engineer              35000.0  425000.0  145840.611624
# Senior Data Scientist             45000.0  890000.0  154206.292996
# Software Engineer                 28000.0  375000.0  113393.760054
#
#                           salary_hour_avg
#                                       min    max       mean
# job_title_short
# ...

# %%
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Bhutan                 3
# Lesotho                3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
df['job_country'].value_counts().head(10)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Germany'])
# Out:
# 108804    False
# 96906     False
# 98438     False
# 110290    False
# 72158     False
#           ...
# 362129    False
# 351830    False
# 327439    False
# 112373    False
# 90102     False
# Name: job_country, Length: 785741, dtype: bool

# %%
germ_jobs = df[df['job_country'] == 'Germany']

# %%
germ_jobs
# Out:
#               job_title_short  \
# 96627            Data Analyst
# 100441         Data Scientist
# 101466         Data Scientist
# 83083   Senior Data Scientist
# 100646  Senior Data Scientist
# ...                       ...
# 299910   Senior Data Engineer
# 390123       Business Analyst
# 741919          Data Engineer
# 742332      Software Engineer
# 721540      Software Engineer
#
#                                                 job_title  \
# 96627                Junior Customer Data Analyst (m/w/d)
# 100441  Expert Data Scientist (m/f/d) - Entwicklung, P...
# 101466                      Junior Data Scientist (m/w/d)
# 83083   Senior Manager Data Science and Analytics (all...
# 100646  Senior Manager Data Science and Analytics (all...
# ...                                                   ...
# 299910              Senior Data Engineer AI (all genders)
# 390123  Mathematiker (m/w/d) Jahresabschluss, Reservie...
# 741919                              Data Engineer (m/w/d)
# ...

# %%
germ_jobs = germ_jobs[germ_jobs['salary_year_avg'].notna()]

# %%
germ_jobs.groupby('job_title_short').count()
# Out:
#                            job_title  job_location  job_via  \
# job_title_short
# Business Analyst                  11            11       11
# Cloud Engineer                     7             7        7
# Data Analyst                      48            48       48
# Data Engineer                     39            39       39
# Data Scientist                    41            41       41
# Machine Learning Engineer         39            39       39
# Senior Data Analyst               15            15       15
# Senior Data Engineer              26            26       26
# Senior Data Scientist             21            21       21
# Software Engineer                 10            10       10
#
#                            job_schedule_type  job_work_from_home  \
# job_title_short
# Business Analyst                          11                  11
# Cloud Engineer                             7                   7
# Data Analyst                              48                  48
# ...

# %%
germ_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'count'])
# Out:
#                                min       max  count
# job_title_short
# Business Analyst           29900.0  126000.0     11
# Cloud Engineer             80850.0  200000.0      7
# Data Analyst               51014.0  200000.0     48
# Data Engineer              56700.0  200000.0     39
# Data Scientist             56700.0  192000.0     41
# Machine Learning Engineer  44418.5  224500.0     39
# Senior Data Analyst        57600.0  119400.0     15
# Senior Data Engineer       72900.0  155500.0     26
# Senior Data Scientist      80850.0  224500.0     21
# Software Engineer          56700.0  177283.0     10

# %%
germ_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max', 'count']).sort_values('max', ascending = False)
# Out:
#                                min       max  count
# job_title_short
# Machine Learning Engineer  44418.5  224500.0     39
# Senior Data Scientist      80850.0  224500.0     21
# Cloud Engineer             80850.0  200000.0      7
# Data Analyst               51014.0  200000.0     48
# Data Engineer              56700.0  200000.0     39
# Data Scientist             56700.0  192000.0     41
# Software Engineer          56700.0  177283.0     10
# Senior Data Engineer       72900.0  155500.0     26
# Business Analyst           29900.0  126000.0     11
# Senior Data Analyst        57600.0  119400.0     15

# %%
import matplotlib.pyplot as plt

# %%
df.job_title_short.value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
job_counts = df.job_title_short.value_counts()

# %%
job_counts
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
plt.bar(job_counts.index,job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(job_counts.index,job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = job_counts.sort_values(ascending=True)
plt.barh(job_counts.index,job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts.plot(kind='bar')
# Out:
# <Axes: xlabel='job_title_short'>

# %%
df.head(10)
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
# 104526         Data Analyst                           Jr. Data Analyst
# 73376          Data Analyst                               Data Analyst
# 99184          Data Analyst                               Data Analyst
# 111440         Data Analyst                               Data Analyst
# 100002        Data Engineer               Data Engineer / Data Analyst
#
#              job_location            job_via job_schedule_type  \
# 108804       New York, NY  via CareerBuilder         Full-time
# ...

# %%
germ_jobs
# Out:
#                   job_title_short  \
# 612452        Senior Data Analyst
# 464029  Machine Learning Engineer
# 714476          Software Engineer
# 452314       Senior Data Engineer
# 412269       Senior Data Engineer
# ...                           ...
# 20066                Data Analyst
# 442389  Machine Learning Engineer
# 728098               Data Analyst
# 223840               Data Analyst
# 492716           Business Analyst
#
#                                                 job_title  \
# 612452              (Senior) Product Data Analyst (f/m/x)
# 464029              Engineering Manager, Machine Learning
# 714476  Software Developer Computer Vision for Interio...
# 452314                 Senior Cloud Data Engineer (m/w/d)
# 412269                 Senior Cloud Data Engineer (m/f/d)
# ...                                                   ...
# 20066                       Data Analyst Logistik (w/m/d)
# 442389                           AI and ML Engineer, Lead
# ...

# %% [markdown]
# ## ADVANCED

# %%
df.iloc[0:10,0:2]
# Out:
#             job_title_short                                  job_title
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
# 104526         Data Analyst                           Jr. Data Analyst
# 73376          Data Analyst                               Data Analyst
# 99184          Data Analyst                               Data Analyst
# 111440         Data Analyst                               Data Analyst
# 100002        Data Engineer               Data Engineer / Data Analyst

# %%
df.loc[0:5]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 4606    Senior Data Engineer
# 13274          Data Engineer
# 9617    Senior Data Engineer
# 6426    Senior Data Engineer
# ...                      ...
# 478514     Software Engineer
# 476674          Data Analyst
# 484399   Senior Data Analyst
# 481181          Data Analyst
# 5              Data Engineer
#
#                                                 job_title       job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...      Watertown, CT
# 4606                                 Senior Data Engineer         Dulles, VA
# 13274            Data Engineer Data Bricks Python RESTful        Holmdel, NJ
# 9617                                 Senior Data Engineer        Anaheim, CA
# 6426                                 Senior Data Engineer  St Louis Park, MN
# ...                                                   ...                ...
# ...

# %%
df.loc[:, 'job_country':'salary_hour_avg'].dropna(subset='salary_hour_avg')
# Out:
#           job_country salary_rate  salary_year_avg  salary_hour_avg
# 109837  United States        hour              NaN        20.000000
# 344960  United States        hour              NaN        20.000000
# 154632  United States        hour              NaN        15.000000
# 367162  United States        hour              NaN        36.000000
# 211228  United States        hour              NaN        55.000000
# ...               ...         ...              ...              ...
# 394963          Sudan        hour              NaN        10.000000
# 529105  United States        hour              NaN        24.969999
# 535511  United States        hour              NaN        66.839996
# 349044  United States        hour              NaN        28.000000
# 327527       Cameroon        hour              NaN        25.000000
#
# [10662 rows x 4 columns]

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
median_salary_hour = df['salary_hour_avg'].median()

# %%
#FILLNA

df_filled = df

df_filled['salary_year_avg'].fillna(median_salary_year)
# Out:
# 108804    115000.0
# 96906     115000.0
# 98438     115000.0
# 110290    115000.0
# 72158     115000.0
#             ...
# 362129    115000.0
# 351830    115000.0
# 327439    140000.0
# 112373    115000.0
# 90102     115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_filled['salary_year_avg']
# Out:
# 108804         NaN
# 96906          NaN
# 98438          NaN
# 110290         NaN
# 72158          NaN
#             ...
# 362129         NaN
# 351830         NaN
# 327439    140000.0
# 112373         NaN
# 90102          NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_year_avg']
# Out:
# 108804    115000.0
# 96906     115000.0
# 98438     115000.0
# 110290    115000.0
# 72158     115000.0
#             ...
# 362129    115000.0
# 351830    115000.0
# 327439    140000.0
# 112373    115000.0
# 90102     115000.0
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_salary_hour)
df_filled['salary_hour_avg']
# Out:
# 108804    45.98
# 96906     45.98
# 98438     45.98
# 110290    45.98
# 72158     45.98
#           ...
# 362129    45.98
# 351830    45.98
# 327439    45.98
# 112373    45.98
# 90102     45.98
# Name: salary_hour_avg, Length: 785741, dtype: float64

# %%
# DROP DUPLICATES (rows)
df_unique = df_filled

df_unique = df_unique.drop_duplicates()
df_unique
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df_unique = df_unique.drop_duplicates(subset = ['job_title', 'company_name'])
df_unique
# Out:
#             job_title_short  \
# 108804         Data Analyst
# 96906          Data Analyst
# 98438          Data Analyst
# 110290         Data Analyst
# 72158   Senior Data Analyst
# ...                     ...
# 369494         Data Analyst
# 336156       Data Scientist
# 351830        Data Engineer
# 327439        Data Engineer
# 112373  Senior Data Analyst
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 369494                                       Data analyst
# 336156         Data Scientist III with Security Clearance
# 351830                                      Data engineer
# ...

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 484812               Data Analyst
# 672192             Data Scientist
# 11160   Machine Learning Engineer
# 233382              Data Engineer
# 747987             Data Scientist
# 101660             Data Scientist
# 777607             Cloud Engineer
# 93174                Data Analyst
# 251009        Senior Data Analyst
# 475155               Data Analyst
#
#                                           job_title  \
# 484812                      Production Data Analyst
# 672192                            Data Science Lead
# 11160                            Algorithm Engineer
# 233382                                Data Engineer
# 747987                               Data Scientist
# 101660  MU-74] Data Scientist (Python/SQL) - Remote
# 777607                        Junior Azure Engineer
# 93174                     Data Architect- Team Lead
# 251009            Senior Product Data Analyst, Core
# 475155                 Data Analyst, Banking System
#
# ...

# %%
#to retain the same samples
df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 636963    Senior Data Analyst
# 745739       Business Analyst
# 702914          Data Engineer
# 372941  Senior Data Scientist
# 32841     Senior Data Analyst
# 19374          Data Scientist
# 207722   Senior Data Engineer
# 341829       Business Analyst
# 47374           Data Engineer
# 386370          Data Engineer
#
#                                                job_title  \
# 636963                             HR Decision Scientist
# 745739  Business Intelligence Analyst, ANSA Polymer Ltd.
# 702914                          Data Engineer Internship
# 372941                             Senior Data Scientist
# 32841                                Senior Data Analyst
# 19374                          Data Scientist Junior H/F
# 207722                              Senior Data Engineer
# 341829                    Senior BI Analyst (Qlik & SQL)
# 47374                                      Data Engineer
# ...

# %%
df.pivot_table
# Out:
# <bound method DataFrame.pivot_table of                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# ...

# %%
df.pivot_table(index='job_title_short',aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table(index='job_title_short',aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.pivot_table( index='job_title_short', values = 'salary_year_avg', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                  115000.0
# Cloud Engineer                    115000.0
# Data Analyst                      115000.0
# Data Engineer                     115000.0
# Data Scientist                    115000.0
# Machine Learning Engineer         115000.0
# Senior Data Analyst               115000.0
# Senior Data Engineer              115000.0
# Senior Data Scientist             115000.0
# Software Engineer                 115000.0

# %%
df.pivot_table( index='job_title_short', values='salary_year_avg', columns='job_country', aggfunc='median')
# Out:
# job_country                Afghanistan   Albania   Algeria    Angola  \
# job_title_short
# Business Analyst              115000.0  115000.0  115000.0  115000.0
# Cloud Engineer                     NaN  115000.0  115000.0       NaN
# Data Analyst                  115000.0  115000.0  115000.0  115000.0
# Data Engineer                      NaN  115000.0  115000.0  115000.0
# Data Scientist                115000.0  115000.0  115000.0  115000.0
# Machine Learning Engineer          NaN  115000.0  115000.0       NaN
# Senior Data Analyst           115000.0  115000.0       NaN       NaN
# Senior Data Engineer               NaN  115000.0  115000.0       NaN
# Senior Data Scientist              NaN  115000.0       NaN  115000.0
# Software Engineer                  NaN  115000.0  115000.0  115000.0
#
# job_country                Argentina   Armenia  Australia   Austria  \
# job_title_short
# Business Analyst            115000.0  115000.0   115000.0  115000.0
# ...

# %%
df.pivot_table(index='job_country', values='salary_year_avg', columns='job_title_short', aggfunc='median')
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan              115000.0             NaN      115000.0
# Albania                  115000.0        115000.0      115000.0
# Algeria                  115000.0        115000.0      115000.0
# Angola                   115000.0             NaN      115000.0
# Argentina                115000.0        115000.0      115000.0
# ...                           ...             ...           ...
# Venezuela                115000.0        115000.0      115000.0
# Vietnam                  115000.0        115000.0      115000.0
# Yemen                    115000.0             NaN      115000.0
# Zambia                   115000.0        115000.0      115000.0
# Zimbabwe                 115000.0        115000.0      115000.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN        115000.0                        NaN
# ...

# %%
#finding top 6 countries
top_countries = df['job_country'].value_counts()
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Mauritania             3
# Bhutan                 3
# Lesotho                3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
top_countries = df['job_country'].value_counts().head(6)
top_countries
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Name: count, dtype: int64

# %%
#Extract the index
top_countries = df['job_country'].value_counts().head(6).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany',
#        'Spain'],
#       dtype='object', name='job_country')

# %%
df_top_country = df.pivot_table(
    index='job_country', 
    values='salary_year_avg', 
    columns='job_title_short', 
    aggfunc='mean')

df_top_country = df_top_country.loc[top_countries]
df_top_country
# Out:
# job_title_short  Business Analyst  Cloud Engineer   Data Analyst  \
# job_country
# United States       113900.923575   115240.704492  113688.506362
# India               114861.177001   115000.000000  114756.590917
# United Kingdom      114604.353083   115000.000000  114824.230681
# France              114862.432249   114973.278107  114878.922807
# Germany             114522.460220   115170.634921  114909.553639
# Spain               114985.980066   114869.582011  114864.820166
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States    116597.655722   116930.687709              120453.603692
# India            115073.696044   115022.195911              114691.857675
# United Kingdom   115003.161853   114961.064714              115542.432177
# France           115004.184757   114904.590081              113953.889175
# Germany          115089.252434   115013.739066              114891.616915
# ...

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist', 'Cloud Engineer']
df_top_country = df_top_country[job_titles]
df_top_country
# Out:
# job_title_short   Data Analyst  Data Engineer  Data Scientist  Cloud Engineer
# job_country
# United States    113688.506362  116597.655722   116930.687709   115240.704492
# India            114756.590917  115073.696044   115022.195911   115000.000000
# United Kingdom   114824.230681  115003.161853   114961.064714   115000.000000
# France           114878.922807  115004.184757   114904.590081   114973.278107
# Germany          114909.553639  115089.252434   115013.739066   115170.634921
# Spain            114864.820166  115009.225890   114922.009378   114869.582011

# %%
df_top_country.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df.head(5)
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
df.index
# Out:
# Index([108804,  96906,  98438, 110290,  72158, 104526,  73376,  99184, 111440,
#        100002,
#        ...
#        333055, 368100, 358912, 338569, 336301, 362129, 351830, 327439, 112373,
#         90102],
#       dtype='int64', length=785741)

# %%
#set index
df.index.name = 'job_index'
df.head()
# Out:
#                job_title_short                                  job_title  \
# job_index
# 108804            Data Analyst                               Data Analyst
# 96906             Data Analyst                               Data Analyst
# 98438             Data Analyst                               Data Analyst
# 110290            Data Analyst                               Data Analyst
# 72158      Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#              job_location            job_via job_schedule_type  \
# job_index
# 108804       New York, NY  via CareerBuilder         Full-time
# 96906      Bloomfield, CT  via CareerBuilder         Full-time
# 98438      Washington, DC  via CareerBuilder         Full-time
# 110290        Fairfax, VA  via CareerBuilder         Full-time
# 72158       Worcester, MA       via LinkedIn         Full-time
#
#            job_work_from_home          search_location     job_posted_date  \
# job_index
# ...

# %%
df_germ = df[df['job_country'] == 'Germany']
df_germ
# Out:
#                  job_title_short  \
# job_index
# 96627               Data Analyst
# 100441            Data Scientist
# 101466            Data Scientist
# 83083      Senior Data Scientist
# 100646     Senior Data Scientist
# ...                          ...
# 299910      Senior Data Engineer
# 390123          Business Analyst
# 741919             Data Engineer
# 742332         Software Engineer
# 721540         Software Engineer
#
#                                                    job_title  \
# job_index
# 96627                   Junior Customer Data Analyst (m/w/d)
# 100441     Expert Data Scientist (m/f/d) - Entwicklung, P...
# 101466                         Junior Data Scientist (m/w/d)
# 83083      Senior Manager Data Science and Analytics (all...
# 100646     Senior Manager Data Science and Analytics (all...
# ...                                                      ...
# 299910                 Senior Data Engineer AI (all genders)
# ...

# %%
df_germ.reset_index(inplace=True)
df_germ
# Out:
#        job_index        job_title_short  \
# 0          96627           Data Analyst
# 1         100441         Data Scientist
# 2         101466         Data Scientist
# 3          83083  Senior Data Scientist
# 4         100646  Senior Data Scientist
# ...          ...                    ...
# 27689     299910   Senior Data Engineer
# 27690     390123       Business Analyst
# 27691     741919          Data Engineer
# 27692     742332      Software Engineer
# 27693     721540      Software Engineer
#
#                                                job_title         job_location  \
# 0                   Junior Customer Data Analyst (m/w/d)  Neckarsulm, Germany
# 1      Expert Data Scientist (m/f/d) - Entwicklung, P...     Dresden, Germany
# 2                          Junior Data Scientist (m/w/d)  Neckarsulm, Germany
# 3      Senior Manager Data Science and Analytics (all...     Cologne, Germany
# 4      Senior Manager Data Science and Analytics (all...      Munich, Germany
# ...

# %%
df_germ.set_index('job_index', inplace=True)

# %%
df_germ
# Out:
#                  job_title_short  \
# job_index
# 96627               Data Analyst
# 100441            Data Scientist
# 101466            Data Scientist
# 83083      Senior Data Scientist
# 100646     Senior Data Scientist
# ...                          ...
# 299910      Senior Data Engineer
# 390123          Business Analyst
# 741919             Data Engineer
# 742332         Software Engineer
# 721540         Software Engineer
#
#                                                    job_title  \
# job_index
# 96627                   Junior Customer Data Analyst (m/w/d)
# 100441     Expert Data Scientist (m/f/d) - Entwicklung, P...
# 101466                         Junior Data Scientist (m/w/d)
# 83083      Senior Manager Data Science and Analytics (all...
# 100646     Senior Manager Data Science and Analytics (all...
# ...                                                      ...
# 299910                 Senior Data Engineer AI (all genders)
# ...

# %%
df_us = df[df['job_country'] == 'United States'].copy()
df_us
# Out:
#                      job_title_short  \
# job_index
# 108804                  Data Analyst
# 96906                   Data Analyst
# 98438                   Data Analyst
# 110290                  Data Analyst
# 72158            Senior Data Analyst
# ...                              ...
# 345518                 Data Engineer
# 355927                 Data Engineer
# 359638          Senior Data Engineer
# 112373           Senior Data Analyst
# 90102      Machine Learning Engineer
#
#                                                    job_title  \
# job_index
# 108804                                          Data Analyst
# 96906                                           Data Analyst
# 98438                                           Data Analyst
# 110290                                          Data Analyst
# 72158              Senior Data Analyst / Platform Experience
# ...                                                      ...
# ...

# %%
df_us['job_posted_month'] = df_us['job_posted_date'].dt.strftime('%B')
df_us
# Out:
#                      job_title_short  \
# job_index
# 108804                  Data Analyst
# 96906                   Data Analyst
# 98438                   Data Analyst
# 110290                  Data Analyst
# 72158            Senior Data Analyst
# ...                              ...
# 345518                 Data Engineer
# 355927                 Data Engineer
# 359638          Senior Data Engineer
# 112373           Senior Data Analyst
# 90102      Machine Learning Engineer
#
#                                                    job_title  \
# job_index
# 108804                                          Data Analyst
# 96906                                           Data Analyst
# 98438                                           Data Analyst
# 110290                                          Data Analyst
# 72158              Senior Data Analyst / Platform Experience
# ...                                                      ...
# ...

# %%
df_us_pivot = df_us.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
#we want to use sorted 'job_posted_month' as index
df_us_pivot.reset_index(inplace=True)
df_us_pivot['month_no'] = pd.to_datetime(df_us_pivot['job_posted_month'], format='%B')
df_us_pivot['month_no']
# Out:
# 0    1900-04-01
# 1    1900-08-01
# 2    1900-12-01
# 3    1900-02-01
# 4    1900-01-01
# 5    1900-07-01
# 6    1900-06-01
# 7    1900-03-01
# 8    1900-05-01
# 9    1900-11-01
# 10   1900-10-01
# 11   1900-09-01
# Name: month_no, dtype: datetime64[ns]

# %%
df_us_pivot['month_no'] = pd.to_datetime(df_us_pivot['job_posted_month'], format='%B').dt.month
df_us_pivot['month_no']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_no, dtype: int32

# %%
df_us_pivot.sort_values('month_no', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_us_pivot.set_index('job_posted_month')
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_pivot.drop(columns = 'month_no', inplace=True)

# %%
df_us_pivot.drop(columns = 'index', inplace=True)
df_us_pivot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df_us_pivot.drop(columns = 'index', inplace=True)
#       2 df_us_pivot
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df_us_pivot.set_index('job_posted_month')
df_us_pivot

# %%
df_us_pivot.plot(kind='line')

# %%
top_3 = df_us['job_title_short'].value_counts().head(3)
top_3

# %%
top_3.index

# %%
top_3 = top_3.index.tolist()
top_3

# %%
df_us_pivot[top_3].plot(kind='line')

# %%
pd.read_csv('https://lukeb.co/software_csv')

# %%
df_us_pivot.set_index('job_posted_month', inplace=True)

# %%
df_software = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')
df_software

# %%
df_us_pivot

# %%
df_us_merged = df_us_pivot.merge(df_software, on='job_posted_month')
df_us_merged

# %%
df_us_merged.sum()

# %%
top5 = df_us_merged.sum().sort_values(ascending=False).head()
top5

# %%
top5 = (df_us_merged
        .sum()
        .sort_values(ascending=False)
        .head()
        .index.to_list())
top5

# %%
df_us_merged[top5].plot(kind='bar')

# %%
df_us_merged[top5].plot(kind='line')

# %%
#pd.concat([dataframe1, dtframe2])

#extract job month
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
df

# %%
months = df['job_posted_month'].unique()
months

# %%
{month: month for month in months}

# %%
dict_months={month: df[df['job_posted_month'] == month] for month in months}
dict_months

# %%
dict_months['Jan']

# %%
df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)
df_q1

# %%
df_q1['job_posted_month'].value_counts()

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')

# %%
#EXPORT DATA

# %%
df_q1.to_csv('quarter_1.csv')

# %%
df = pd.read_csv('data_jobs.csv')
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']

# %%
#APPLY FUNCTION

# %%
df_salary = df[pd.notna(df['salary_year_avg'])]
#remove na values
def projected_salary(salary):
    return salary*1.03

df_salary['salary_year_avg'].apply(projected_salary)

# %%
df_salary

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary*1.03)
df_salary[['salary_year_avg', 'salary_year_inflated']]

# %%
#df[pd.notna(df['salary_year_avg'])] -> shows notna values in the selected column
#df[pd.isna(df['salary_year_avg'])] -> shows na values in the selected column

# %%
def projected_salary(row):
    if "Senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']

df_salary['salary_inflated'] = df_salary.apply(projected_salary, axis=1)
df_salary[['job_title_short', 'salary_year_avg', 'salary_inflated']]

#applyting the function, with row as argument

# %%
df_salary['salary_year_avg'].dtype

# %%
df_exploded = df.explode('job_skills')
df_exploded

# %%
df_exploded['job_skills'].value_counts().head(10)

# %%
df_exploded['job_skills'].value_counts().head(10).plot(kind='bar')

# %%
df_ds = df[df['job_title_short'] == 'Data Scientist'].copy()
df_ds

# %%
df_ds['job_posted_month_no'] = df_ds['job_posted_date'].dt.month
df_ds

# %%
df_ds['job_posted_date']

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)
df_ds['job_posted_date'] = pd.to_datetime(df_ds.job_posted_date)

# %%
df_ds['job_posted_date']

# %%
df_ds['job_posted_month_no'] = df_ds['job_posted_date'].dt.month
df_ds

# %%
import ast

#In order for us to use explaode in job skills column
df_ds['job_skills'] = df_ds['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
df_ds_explode = df_ds.explode('job_skills')
df_ds_explode

# %%
df_ds_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

# %%
df_ds_pivot = df_ds_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)
df_ds_pivot

# %%
df_ds_pivot.loc['Total'] = df_ds_pivot.sum()
#create a total column
df_ds_pivot

# %%
df_ds_pivot.loc['Total'].sort_values(ascending=False)

# %%
df_ds_pivot.loc['Total'].sort_values(ascending=False).index

# %%
df_ds_pivot  = df_ds_pivot[df_ds_pivot.loc['Total'].sort_values(ascending=False).index]
df_ds_pivot

# %%
df_ds_pivot = df_ds_pivot.drop('Total', axis=0)
df_ds_pivot

# %%
df_ds_pivot.iloc[:, :5]

# %%
df_ds_pivot.iloc[:, :5].plot(kind='line')

# %%
fig, ax = plt.subplots(2,2)

# %%
df['job_title_short'].value_counts()

# %%
fig, ax = plt.subplots()
df['job_title_short'].value_counts().plot(kind='bar', ax=ax)

# %%
fig, ax = plt.subplots(1,2)
df['job_title_short'].value_counts().plot(kind='bar', ax=ax[0])
df['job_schedule_type'].value_counts().head(3).plot(kind='bar', ax=ax[1])

# %%
df['job_title_short'].value_counts().plot(kind='bar')

# %%
df['job_title_short'].value_counts().plot(kind='pie')

# %%
df['job_title_short'].value_counts().plot(kind='pie', startangle=45, autopct='%1.2f%%')

# %%
fig, ax = plt.subplots(1,3)

dict_column = {
    'job_work_from_home': 'Work from Home',
    'job_no_degree_mention': 'Job Degree Req',
    'job_health_insurance': 'Health Insurance Offered'
}

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), startangle=90, autopct='%1.1f%%')
    ax[i].set_title(title)

plt.show()

# %%
df_da = df[df['job_title_short'] == 'Data Analyst']

# %%
df_da['job_skills'] = df_da['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_da_exploded = df_da.explode('job_skills')
df_da_exploded

# %%
df_da_exploded.groupby('job_skills').size()

# %%
skill_stats = df_da_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary = ('salary_year_avg', 'median')
)

skill_stats

# %%
skill_stats.sort_values('skill_count', ascending=False).head(10)

# %%
skills_stats = skill_stats.sort_values('skill_count', ascending=False).head(10)
skills_stats.plot(kind = 'scatter', x='skill_count', y='median_salary')

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()
# create a new column for month number
df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

# Explode the job_skills column and pivot
df_DA_explode= df_DA.explode('job_skills')
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills',  aggfunc='size', fill_value=0)

# sort the skills by count
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')

# Use month names for plotting
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month'] = df_DA_pivot['job_posted_month_no'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))
df_DA_pivot = df_DA_pivot.set_index('job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month_no')

# Get the top 5 skills
df_DA_pivot.iloc[:, :5].plot(kind='line')

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind='line',
    linewidth=4,
    linestyle=':', # options: '-', '--', '-.', ':'
    colormap='viridis', # options: 'viridis', 'plasma', 'inferno', 'magma', 'cividis' 
    markersize=5,
    marker='o', # options: 'o', 'x', '+', '*', 's', ',', '.', '1', '2', '3', '4', ...
    figsize=(10, 5)
)

plt.title('Top 5 Skills for Data Analysts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %%
# Importing Libraries
import ast
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
df_DA_US['salary_year_avg'].plot(kind='hist', bins=5, edgecolor='black')
plt.xlim(0,200000)
# Out:
# (0.0, 200000.0)

# %%
df_DA_US['salary_year_avg'].sample(10)
# Out:
# job_index
# 158808    115000.0
# 541968    115000.0
# 102433    115000.0
# 498336    115000.0
# 200523    115000.0
# 184616    115000.0
# 247278    115000.0
# 259618    115000.0
# 692582    115000.0
# 455776    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df = pd.read_csv('data_jobs.csv')

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

df_g = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'Germany')].copy()

# Drop NaN values from the 'salary_year_avg' column for accurate visualization
df_g = df_g.dropna(subset=['salary_year_avg'])

# %%
df_g
# Out:
#        job_title_short                                          job_title  \
# 20066     Data Analyst                      Data Analyst Logistik (w/m/d)
# 51100     Data Analyst               (Senior) People Data Analyst (m/w/x)
# 51476     Data Analyst                             Head of Data Analytics
# 56790     Data Analyst  Data Analyst / Data Scientist eBike Systems (w...
# 57582     Data Analyst         Application Consultant in Data Integration
# 58368     Data Analyst                                       Data Manager
# 89707     Data Analyst  Manager Data Strategy - German speaking (all g...
# 110336    Data Analyst                             Data Operation Analyst
# 127888    Data Analyst                                       Data Analyst
# 137735    Data Analyst                               Data Manager (m/w/d)
# 161026    Data Analyst  Research Engineer for Security and Privacy  (f...
# 181422    Data Analyst  Senior Product and Service Owner "Big Data - K...
# ...

# %%
df_g = df_g.explode('job_skills')
df_g[['salary_year_avg', 'job_skills']].head(5)
# Out:
#        salary_year_avg job_skills
# 20066          75067.5          r
# 20066          75067.5     python
# 20066          75067.5       java
# 20066          75067.5         c#
# 20066          75067.5        sql

# %%
df_g_group = df_g.groupby('job_skills')['salary_year_avg'].agg(['count','median'])
df_g_group
# Out:
#                count     median
# job_skills
# atlassian          1  102500.00
# aws                3  100500.00
# azure              3   89100.00
# bigquery           1  166419.50
# c#                 2   82083.75
# databricks         1  111175.00
# elasticsearch      1  111175.00
# excel              7  105650.00
# flask              1  111175.00
# gcp                3  165000.00
# git                1  105000.00
# github             3  199675.00
# go                 4   52014.00
# java               1   75067.50
# javascript         1  111175.00
# julia              1   89100.00
# kafka              1  166419.50
# linux              1   89100.00
# looker             5   53014.00
# matlab             1  111175.00
# matplotlib         3  105650.00
# neo4j              1   89100.00
# no-sql             1  111175.00
# nosql              1  166419.50
# numpy              2  105650.00
# oracle             1   56700.00
# pandas             4  108412.50
# pascal             1   92000.00
# ...

# %%
df_g_top_pay = df_g_group.sort_values('median', ascending=False).head(10)
df_g_top_pay
# Out:
#             count    median
# job_skills
# github          3  199675.0
# terraform       1  166419.5
# bigquery        1  166419.5
# redshift        1  166419.5
# nosql           1  166419.5
# kafka           1  166419.5
# gcp             3  165000.0
# javascript      1  111175.0
# terminal        1  111175.0
# spark           7  111175.0

# %%
df_g_skills = df_g_group.sort_values('count', ascending=False).head(10).sort_values('median', ascending=False)
df_g_skills
# Out:
#             count    median
# job_skills
# python         18  111175.0
# spark           7  111175.0
# pandas          4  108412.5
# excel           7  105650.0
# sql            24  101500.0
# tableau        13  100500.0
# power bi        4   83937.5
# r               7   75067.5
# looker          5   53014.0
# go              4   52014.0

# %%
fig, ax = plt.subplots(2,1)

df_g_top_pay.plot(kind = 'barh', y = 'median', ax = ax[0])
df_g_skills.plot(kind = 'barh', y = 'median', ax = ax[1])
# Out:
# <Axes: ylabel='job_skills'>

# %%
fig, ax = plt.subplots(2,1)

df_g_top_pay.plot(kind = 'barh', y = 'median', ax = ax[0])
ax[0].invert_yaxis()

df_g_skills.plot(kind = 'barh', y = 'median', ax = ax[1])
ax[1].invert_yaxis()

# %%
fig, ax = plt.subplots(2,1)

df_g_top_pay.plot(kind = 'barh', y = 'median', ax = ax[0], legend=False)
ax[0].invert_yaxis()
ax[0].set_xlabel('')
ax[0].set_ylabel('')

df_g_skills.plot(kind = 'barh', y = 'median', ax = ax[1],  legend=False)
ax[1].invert_yaxis()

# %%
fig, ax = plt.subplots(2,1)

df_g_top_pay.plot(kind = 'barh', y = 'median', ax = ax[0], legend=False)
ax[0].invert_yaxis()
ax[0].set_xlabel('')
ax[0].set_ylabel('')

df_g_skills.plot(kind = 'barh', y = 'median', ax = ax[1],  legend=False)
ax[1].invert_yaxis()
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary (USD)')
# Out:
# Text(0.5, 0, 'Median Salary (USD)')

# %%
fig, ax = plt.subplots(2,1)

df_g_top_pay.plot(kind = 'barh', y = 'median', ax = ax[0], legend=False)
ax[0].invert_yaxis()
ax[0].set_xlabel('')
ax[0].set_ylabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))

df_g_skills.plot(kind = 'barh', y = 'median', ax = ax[1],  legend=False)
ax[1].invert_yaxis()
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary (USD)')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
